# %% [markdown]
# # Question 01
# ### 最初に左上のFileメニューから「Make a Copy」を選び、コピーが表示されてから、左上のFileメニューから「Rename」を選び、ご自分の名前を含むファイル名にしてから始めてください。
# ### (元のファイルがなくなると、後でプッシュする際にリポジトリーからの削除を意味することになりますので、ご注意ください)
# ## 与えられたデータフレームのある列に、特定の値がある行だけからなるデータフレームを求めてください。
# ### 例: 下のデータフレームdfの「Q9_ファンデーションのタイプ(V)」列の値が「パウダリータイプ」の行だけからなるデータフレームを求めてください。

# %%
import pandas as pd
df = pd.read_csv('../data/foundation.csv', encoding='cp932')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4e5c7d4d27dc> in <module>()
#       1 import pandas as pd
#       2 df = pd.read_csv('../data/foundation.csv', encoding='cp932')
# ----> 3 df[['Q9_ファンデーションのタイプ(V)'].isin(['パウダリータイプ'])]
#       4 df.head()
#
# AttributeError: 'list' object has no attribute 'isin'

# %%
df[df['Q9_ファンデーションのタイプ(V)'].isin(['パウダリータイプ'])]
# Out:
#        SampleID  Q-001使用している Q-002使用中のブランド(V)  \
# 1             2            1              その他
# 2             3            1              ちふれ
# 3             4            1              その他
# 4             5            1              その他
# 6             7            1              その他
# 7             8            1              その他
# 8             9            1              その他
# 9            10            1            ルティーナ
# 10           11            1             ファシオ
# 11           12            1             レヴュー
# 12           13            1              その他
# 15           16            1           プラウディア
# 16           17            1            レイシャス
# 17           18            1             オルビス
# 19           20            1           CHANEL
# 20           21            1             セザンヌ
# 21           22            1              その他
# 22           23            1              その他
# 23           24            1             レヴュー
# ...

# %%
df[df['Q9_ファンデーションのタイプ(V)'] == 'パウダリータイプ']
# Out:
#        SampleID  Q-001使用している Q-002使用中のブランド(V)  \
# 1             2            1              その他
# 2             3            1              ちふれ
# 3             4            1              その他
# 4             5            1              その他
# 6             7            1              その他
# 7             8            1              その他
# 8             9            1              その他
# 9            10            1            ルティーナ
# 10           11            1             ファシオ
# 11           12            1             レヴュー
# 12           13            1              その他
# 15           16            1           プラウディア
# 16           17            1            レイシャス
# 17           18            1             オルビス
# 19           20            1           CHANEL
# 20           21            1             セザンヌ
# 21           22            1              その他
# 22           23            1              その他
# 23           24            1             レヴュー
# ...
