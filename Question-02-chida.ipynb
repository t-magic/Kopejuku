# %% [markdown]
# # Question 02
# ### 最初に左上のFileメニューから「Make a Copy」を選び、コピーが表示されてから、左上のFileメニューから「Rename」を選び、ご自分の名前を含むファイル名にしてから始めてください。
# ### (元のファイルがなくなると、後でプッシュする際にリポジトリーからの削除を意味することになりますので、ご注意ください)
# ## 与えられたデータフレームの指定された複数の列だけからなるデータフレームを求めてください。
# ### 例: 下のデータフレームdfの「Q7_年代(V)」列と「Q9_ファンデーションのタイプ(V)」列だけからなるデータフレームを求めてください。

# %%
import pandas as pd
df = pd.read_csv('../data/foundation.csv', encoding='cp932')
df.head()
# Out:
#    SampleID  Q-001使用している Q-002使用中のブランド(V)            Q3_好きなところ(FA)  \
# 0         1            1             オルビス                 じぶんにあってる
# 1         2            1              その他    しっとり肌になじむ感じ、粉っぽく浮かない。
# 2         3            1              ちふれ                       安い
# 3         4            1              その他  毛穴が消える。厚くならない。表情が明るくなる。
# 4         5            1              その他   あんまりぬらなくてもかばーしてくれるところ。
#
#   Q4_嫌いなところ(FA) Q5_他に使用してみたいブランドの有無(V) Q5_2_他に使用してみたいブランド(V)        Q6_理由(FA)  \
# 0           たかい                     ない                   NaN              NaN
# 1         値段が高い                     ない                   NaN              NaN
# 2       ケースがダサい                     ない                   NaN              NaN
# 3       長持ちしない。                     ない                   NaN              NaN
# 4       てかりやすい。                     ある                プラウディア  宣伝のかんじがよさそうだから。
#
#   Q7_年代(V)  Q8_婚姻(V) Q9_ファンデーションのタイプ(V)         Q10_購入場所(V)  \
# 0   40-49歳  既婚（子供あり）            クリームタイプ  ブランド専門のインターネット通信販売
# 1   25-29歳        未婚           パウダリータイプ      インターネット以外の通信販売
# 2   30-34歳  既婚（子供なし）           パウダリータイプ             ドラッグストア
# 3   25-29歳        未婚           パウダリータイプ             ドラッグストア
# 4   20-24歳        未婚           パウダリータイプ                デパート
#
#                                 Q11_感じていること・要望など(FA)
# 0                                          じぶんにあえばよい
# 1    試供品があれば一番いいですけど、せめて２００円ぐらいのお試しサイズが各商品にあるといいですね。
# 2                                 どのタイプが自分に合うのかわからない
# 3  買って使ってみないと、わからない。いいお値段がするのでいつも迷う。お試し用みたいのがあると嬉しい。
# 4                                             価格が高い。

# %%
import pandas as pd
df = pd.read_csv('../data/foundation.csv', encoding='cp932')
df.loc[:,['Q7_年代(V)','Q9_ファンデーションのタイプ(V)']]
# Out:
#       Q7_年代(V) Q9_ファンデーションのタイプ(V)
# 0       40-49歳            クリームタイプ
# 1       25-29歳           パウダリータイプ
# 2       30-34歳           パウダリータイプ
# 3       25-29歳           パウダリータイプ
# 4       20-24歳           パウダリータイプ
# 5       40-49歳            リキッドタイプ
# 6       40-49歳           パウダリータイプ
# 7        60歳以上           パウダリータイプ
# 8       40-49歳           パウダリータイプ
# 9       30-34歳           パウダリータイプ
# 10      30-34歳           パウダリータイプ
# 11      25-29歳           パウダリータイプ
# 12      40-49歳           パウダリータイプ
# 13      35-39歳            クリームタイプ
# 14      30-34歳            クリームタイプ
# 15      40-49歳           パウダリータイプ
# 16      35-39歳           パウダリータイプ
# 17      50-59歳           パウダリータイプ
# 18      50-59歳            リキッドタイプ
# 19       19歳以下           パウダリータイプ
# 20      25-29歳           パウダリータイプ
# 21      20-24歳           パウダリータイプ
# 22       19歳以下           パウダリータイプ
# 23      30-34歳           パウダリータイプ
# 24      25-29歳           パウダリータイプ
# 25      40-49歳           パウダリータイプ
# 26      30-34歳           パウダリータイプ
# 27      30-34歳           パウダリータイプ
# 28      25-29歳           パウダリータイプ
# 29      30-34歳           パウダリータイプ
# ...        ...                ...
# 10829   35-39歳            リキッドタイプ
# 10830   50-59歳            リキッドタイプ
# 10831   20-24歳            リキッドタイプ
# 10832   35-39歳           パウダリータイプ
# 10833   35-39歳            リキッドタイプ
# 10834   20-24歳           パウダリータイプ
# 10835    19歳以下           パウダリータイプ
# 10836   35-39歳           パウダリータイプ
# 10837   35-39歳           パウダリータイプ
# 10838   30-34歳            リキッドタイプ
# 10839   30-34歳           パウダリータイプ
# 10840   40-49歳           パウダリータイプ
# 10841   25-29歳            クリームタイプ
# 10842   20-24歳                その他
# 10843   20-24歳            リキッドタイプ
# 10844   35-39歳           パウダリータイプ
# 10845   35-39歳           パウダリータイプ
# 10846   30-34歳           パウダリータイプ
# 10847   30-34歳           パウダリータイプ
# 10848   35-39歳           パウダリータイプ
# 10849   30-34歳            リキッドタイプ
# 10850   20-24歳            リキッドタイプ
# 10851   40-49歳           パウダリータイプ
# 10852   30-34歳           パウダリータイプ
# 10853   35-39歳           パウダリータイプ
# 10854   35-39歳           パウダリータイプ
# 10855   20-24歳            リキッドタイプ
# 10856   25-29歳            クリームタイプ
# 10857   25-29歳           パウダリータイプ
# 10858   30-34歳           パウダリータイプ
#
# [10859 rows x 2 columns]
